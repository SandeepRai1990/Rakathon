# %% [markdown]
# # Considering an image of a product accompanied by its attributes, user reviews, and rating information.

# %% [markdown]
# ![cooker.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ![pressure cooker.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ![bags.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ![water_bottle.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# # Generate Text Prompt from
#
# * **Social Media** : Trends extracted from reviews and product description.
# * **User insights** : Based on location(pincode):  allowed voltage, battery life, service center.
# * **Based on time of year** : Diwali, Christmas, vacation, rainy, winter, cold etc.
# * **product profiles** : Based on product description and aspects.

# %% [markdown]
# # Prompt refinement:
# A prompt refinement is needed in this context to ensure its logical alignment with the accompanying image. e.x. voltage, battery life not required for clothing’s.
#
# *   We can utilize image captioning/description or visual QA approach.
# *   Topic Modelling.

# %% [markdown]
# # Product Segmentation

# %%
from IPython.display import Javascript
def open_web():
    url = 'https://huggingface.co/mattmdjaga/segformer_b2_clothes'
    display(Javascript('window.open("{url}");'.format(url=url)))

# %%
open_web()

# %% [markdown]
# ![seg-cooker.PNG](data:image/png;base64,...)

# %% [markdown]
# ![seg-bag.PNG](data:image/png;base64,...)

# %% [markdown]
# ![seg-Sipper.PNG](data:image/png;base64,...)

# %% [markdown]
# ![seg-full-me.png](data:image/png;base64,...)

# %% [markdown]
# # Developing multi-model embeddings for both text and image data.

# %% [markdown]
# # Perform a search using vector embeddings for existing products, utilizing technologies like Weaviate, Vertex AI, or frameworks that implement a Retrieval-Augmented Generation (RAG) approach.
